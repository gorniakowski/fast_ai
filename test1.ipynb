# %% [markdown]
# <a href="https://colab.research.google.com/github/gorniakowski/fast_ai/blob/master/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is some configs to jupite netbook

# %%
#%reload_ext autoreload
#%autoreload 2
#%matplotlib inline

# %% [markdown]
# Import fast ai library

# %%
from fastai import *
from fastai.vision import *

# %%
help(untar_data)
# Out:
# Help on function untar_data in module fastai.datasets:
#
# untar_data(url:str, fname:Union[pathlib.Path, str]=None, dest:Union[pathlib.Path, str]=None, data=True, force_download=False) -> pathlib.Path
#     Download `url` to `fname` if it doesn't exist, and un-tgz to folder `dest`.

# %%
path = untar_data(URLs.PETS)
print (path)
path.ls()
# Out:
# /root/.fastai/data/oxford-iiit-pet
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/annotations')]

# %%
path_annotations = path/'annotations'
path_img = path/'images'
file_names = get_image_files(path_img)
file_names[:4]
# Out:
# [PosixPath('/root/.fastai/data/oxford-iiit-pet/images/english_cocker_spaniel_10.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Egyptian_Mau_171.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/staffordshire_bull_terrier_47.jpg'),
#  PosixPath('/root/.fastai/data/oxford-iiit-pet/images/Birman_187.jpg')]

# %%
pat = r'/([^/]+)_\d+.jpg$'
data= ImageDataBunch.from_name_re(path_img, file_names, pat, ds_tfms=get_transforms(), size=224)
data
data.normalize(imagenet_stats)
data.show_batch(rows=3, figsize=(7,6))
